# %% [markdown]
# <a href="https://colab.research.google.com/github/hantswilliams/google-colab/blob/main/hha507class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading packages

# %%
import pandas as pd
import seaborn as sns
import plotly as plt

# %%
# !pip freeze > packages.txt

# %% [markdown]
# # Creating Functions

# %%
def bloodpress(systolic, diastolic):
  total = systolic + diastolic
  return total

# %%
def bloodsugar(value):
  valuetoprint = f"Your blood sugar is {value}"
  return valuetoprint

# %% [markdown]
# # Testing Function

# %%
# Test for Blood Pressure

test1 = bloodpress(190, 155)
test1
# Out:
# 345

# %%
test2 = bloodsugar(200)
print(test2)
# Out:
# Your blood sugar is 200

# %%
test3 = bloodsugar(500)
print(test3)
# Out:
# Your blood sugar is 500

# %%
print(f"\n {test2} \n {test3}")
# Out:
#  Your blood sugar is 200
#  Your blood sugar is 500

# %% [markdown]
# # Pandas data loading

# %% [markdown]
# ## Example 1 with CSV files

# %%
## Loading in the file first
stonybrook_east = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_504_2023/main/WK1/data/113243405_StonyBrookEasternLongIslandHospital_standardcharges.csv')

# %%
stonybrook_east
# Out:
#        Code                                        Description        Type  \
# 0     10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 1     10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 2     10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 3     10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 4     10120  REMOVAL OF FOREIGN BODY FROM TISSUE, ACCESSED ...  Outpatient
# ...     ...                                                ...         ...
# 2983  U0002                                     SARS COV 2 RNA         NaN
# 2984  V2632                                  INTRAOCCULAR LENS         NaN
# 2985  V2632                                       PANOPTIX IOL         NaN
# 2986  V2785                                      CORNEAL GRAFT         NaN
# 2987  V2790                                        AMBIO DRY 2         NaN
#
#      Package/Line_Level  Gross charge  Discounted cash price  \
# 0                  Line        575.75                 575.75
# 1               Package        575.75                 575.75
# 2                  Line        548.00                 548.00
# 3               Package       7675.00                7675.00
# 4                  Line        487.00                 487.00
# ...                 ...           ...                    ...
# 2983                NaN        518.95                    NaN
# 2984                NaN       1696.10                    NaN
# 2985                NaN       2985.00                    NaN
# 2986                NaN      16388.10                    NaN
# 2987                NaN       2211.00                    NaN
#
#       De-identified min contracted rate  De-identified max contracted rate  \
# 0                                384.69                             786.90
# 1                                384.69                             786.90
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                371.66                             371.66
# ...                                 ...                                ...
# 2983                                NaN                                NaN
# 2984                                NaN                                NaN
# 2985                                NaN                                NaN
# 2986                                NaN                                NaN
# 2987                                NaN                                NaN
#
#       Derived contracted rate  AETNA-Commercial HMO/POS  ...  \
# 0                      585.80                       NaN  ...
# 1                      585.80                       NaN  ...
# 2                         NaN                       NaN  ...
# 3                         NaN                       NaN  ...
# 4                      371.66                       NaN  ...
# ...                       ...                       ...  ...
# 2983                      NaN                       NaN  ...
# 2984                      NaN                       NaN  ...
# 2985                      NaN                       NaN  ...
# 2986                      NaN                       NaN  ...
# 2987                      NaN                       NaN  ...
#
#       HandM-Commercial HMO/POS  HEALTHFIRST-Commercial HMO/POS  \
# 0                          NaN                          384.69
# 1                          NaN                          384.69
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                          371.66
# ...                        ...                             ...
# 2983                       NaN                             NaN
# 2984                       NaN                             NaN
# 2985                       NaN                             NaN
# 2986                       NaN                             NaN
# 2987                       NaN                             NaN
#
#       BLUE CROSS-Medicaid HMO  UNITED HEALTHCARE-Commercial HMO/POS  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 2983                      NaN                                   NaN
# 2984                      NaN                                   NaN
# 2985                      NaN                                   NaN
# 2986                      NaN                                   NaN
# 2987                      NaN                                   NaN
#
#       UNITED HEALTHCARE-Medicare Advantage HMO  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2983                                       NaN
# 2984                                       NaN
# 2985                                       NaN
# 2986                                       NaN
# 2987                                       NaN
#
#       INTEGRATED HEALTH-Commercial HMO/POS  MOLINA-Medicaid HMO  \
# 0                                      NaN                  NaN
# 1                                      NaN                  NaN
# 2                                      NaN                  NaN
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
# ...                                    ...                  ...
# 2983                                   NaN                  NaN
# 2984                                   NaN                  NaN
# 2985                                   NaN                  NaN
# 2986                                   NaN                  NaN
# 2987                                   NaN                  NaN
#
#       TUFTS HEALTH-Commercial HMO/POS  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 2983                              NaN
# 2984                              NaN
# 2985                              NaN
# 2986                              NaN
# 2987                              NaN
#
#       UNITED HEALTHCARE-Commercial PPO/Open Access  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2983                                           NaN
# 2984                                           NaN
# 2985                                           NaN
# 2986                                           NaN
# 2987                                           NaN
#
#       UNITED HEALTHCARE-Medicaid HMO
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2983                             NaN
# 2984                             NaN
# 2985                             NaN
# 2986                             NaN
# 2987                             NaN
#
# [2988 rows x 29 columns]

# %% [markdown]
# ## Example 2 of loading CSV

# %%
dataset2 = pd.read_csv('sample_data/california_housing_test.csv')
dataset2
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %% [markdown]
# ## Data Example 3

# %%
cancer = pd.read_csv('cancer_deaths.csv')

# %%
cancer
# Out:
#    Years  Historical Data  Target
# 0   2011            191.0     0.0
# 1   2012            189.9     0.0
# 2   2013            185.7     0.0
# 3   2014              0.0     0.0
# 4   2015              0.0     0.0
# 5   2016              0.0     0.0
# 6   2017              0.0     0.0
# 7   2018              0.0     0.0
# 8   2019              0.0   180.3

# %% [markdown]
# ## Data Example 4

# %%
gun_df = pd.read_csv('children_deaths.csv')

# %%
gun_df
# Out:
#       Incident ID      Incident Date       State City Or County  \
# 0         2693825    August 28, 2023       Texas          Allen
# 1         2692267    August 27, 2023     Florida     Lake Wales
# 2         2693375    August 27, 2023   Tennessee       Rockwood
# 3         2690239    August 24, 2023        Ohio      Hartville
# 4         2687183    August 21, 2023       Texas        Lubbock
# ...           ...                ...         ...            ...
# 1995       223284  November 20, 2014     Indiana        Elkhart
# 1996       222932  November 20, 2014  New Jersey     Tabernacle
# 1997       222582  November 18, 2014     Georgia       Savannah
# 1998       220909  November 14, 2014   Louisiana     Shreveport
# 1999       220901  November 14, 2014     Georgia        Decatur
#
#                                Address  Victims Killed  Victims Injured  \
# 0                     1211 Aberdeen Dr               3                0
# 1                                  NaN               2                0
# 2              100 block of Airport Rd               1                0
# 3               13305 Carnation Ave NW               4                0
# 4                         2706 46th St               2                0
# ...                                ...             ...              ...
# 1995       2100 block of Morton Avenue               1                0
# 1996                  Holly Park Drive               4                0
# 1997     200 block of Hampstead Avenue               1                0
# 1998        2700 block DeVaughn Street               1                0
# 1999  4900 block of Hidden Creek Place               1                0
#
#       Suspects Killed  Suspects Injured  Suspects Arrested  Operations
# 0                   1                 0                  0         NaN
# 1                   1                 0                  0         NaN
# 2                   0                 0                  1         NaN
# 3                   1                 0                  0         NaN
# 4                   1                 0                  0         NaN
# ...               ...               ...                ...         ...
# 1995                0                 0                  0         NaN
# 1996                0                 0                  0         NaN
# 1997                0                 0                  0         NaN
# 1998                0                 0                  0         NaN
# 1999                0                 0                  0         NaN
#
# [2000 rows x 11 columns]

# %%
gun_df.columns
# Out:
# Index(['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address',
#        'Victims Killed', 'Victims Injured', 'Suspects Killed',
#        'Suspects Injured', 'Suspects Arrested', 'Operations'],
#       dtype='object')

# %%
gun_df['Victims Killed'].sum()
# Out:
# 2839
